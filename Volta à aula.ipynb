# %% [markdown]
# # Ambiente de Markdown
#
# Este é um espaço que me ajuda a organizar as minhas anotações de forma mais organizada (abaixo eu uso um sinal de menos (-))
# - Execução de códigos
# - Criação de documentos com texto formatador;
# - Plotagem de gráficos.
#
# Esse é um código ideal para fazer a categorização. Para dar uma barra maior, dá para usar um (>)
#
# - Este exemplo com o menos
# > este é com o sinal de maior

# %% [markdown]
# ![sinistro%20de%20carro%203.jpg](attachment:sinistro%20de%20carro%203.jpg)

# %%
import random
random.randint?

# %%
num = 3

# %%
num = num - 2

# %%
num = num *5

# %%
print (num)
# Out:
# 13
